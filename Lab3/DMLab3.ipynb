# %% [markdown]
# # Lab 3: Introduction to pandas

# %% [markdown]
# ### Import important liberires:

# %%
import pandas as pd

# %% [markdown]
# ### Task 1:
# Create data frame with
# * 6 names of dinosaurs.
# * Their favourite prime number.
# * Play around with the frame

# %%
task1= pd.DataFrame({"Dinosaur Name": [ "Aegyptosaurus", "Tyrannosaurus", "Panoplosaurus", "Isisaurus", "Triceratops", "Velociraptor"], 
                     "Favourite Prime": [4,8,15,16,23,42],
                     "Favourite Color": ["blue", "white", "blue", "purple", "violet", "gray"]
                     })

task1
# Out:
#    Dinosaur Name  Favourite Prime Favourite Color
# 0  Aegyptosaurus                4            blue
# 1  Tyrannosaurus                8           white
# 2  Panoplosaurus               15            blue
# 3      Isisaurus               16          purple
# 4    Triceratops               23          violet
# 5   Velociraptor               42            gray

# %%
task1.sort_values("Dinosaur Name")
# Out:
#    Dinosaur Name  Favourite Prime Favourite Color
# 0  Aegyptosaurus                4            blue
# 3      Isisaurus               16          purple
# 2  Panoplosaurus               15            blue
# 4    Triceratops               23          violet
# 1  Tyrannosaurus                8           white
# 5   Velociraptor               42            gray

# %%
task1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Dinosaur Name    6 non-null      object
#  1   Favourite Prime  6 non-null      int64
#  2   Favourite Color  6 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 276.0+ bytes

# %%
task1.sum()
# Out:
# Dinosaur Name      AegyptosaurusTyrannosaurusPanoplosaurusIsisaur...
# Favourite Prime                                                  108
# Favourite Color                        bluewhitebluepurplevioletgray
# dtype: object

# %% [markdown]
# ### Task 2:
# * Read Task2 data as a dataframe and call it df
# * Get to know it and play a bit with it(describe, show head,show
# shape...etc)

# %%
df= pd.read_csv("Task2Data.csv")

# %%
df.describe()
# Out:
#         id     Nodes  Tasks/Node  Threads/Task  Runtime Program / s  Scale  \
# count  8.0  8.000000    8.000000       8.00000             8.000000    8.0
# mean   5.0  1.750000    3.000000       6.00000           118.463750   10.0
# std    0.0  0.707107    1.069045       2.13809            62.073344    0.0
# min    5.0  1.000000    2.000000       4.00000            37.200000   10.0
# 25%    5.0  1.000000    2.000000       4.00000            79.120000   10.0
# 50%    5.0  2.000000    3.000000       6.00000            93.040000   10.0
# 75%    5.0  2.000000    4.000000       8.00000           173.330000   10.0
# max    5.0  3.000000    4.000000       8.00000           202.150000   10.0
#
#        Avg. Neuron Build Time / s  Min. Edge Build Tim  e / s  \
# count                    8.000000                    8.000000
# mean                     0.173750                   29.203750
# std                      0.050973                   13.778026
# ...

# %%
df.head()
# Out:
#    id  Nodes  Tasks/Node  Threads/Task  Runtime Program / s  Scale  Plastic  \
# 0   5      1           4             4               200.84     10     True
# 1   5      1           2             8               202.15     10     True
# 2   5      1           4             8                89.57     10     True
# 3   5      2           2             4               164.16     10     True
# 4   5      2           4             4                77.68     10     True
#
#    Avg. Neuron Build Time / s  Min. Edge Build Tim  e / s  \
# 0                        0.15                       46.03
# 1                        0.28                       47.98
# 2                        0.15                       20.41
# 3                        0.20                       40.03
# 4                        0.13                       20.93
#
#    Max. Edge Build Time / s  ...  Max. Init. Time / s  Presim. Time / s  \
# 0                     46.34  ...                 1.01              7.87
# ...

# %%
df.reset_index().multiply(2).head(3)
# Out:
#    index  id  Nodes  Tasks/Node  Threads/Task  Runtime Program / s  Scale  \
# 0      0  10      2           8             8               401.68     20
# 1      2  10      2           4            16               404.30     20
# 2      4  10      2           8            16               179.14     20
#
#    Plastic  Avg. Neuron Build Time / s  Min. Edge Build Tim  e / s  ...  \
# 0        2                        0.30                       92.06  ...
# 1        2                        0.56                       95.96  ...
# 2        2                        0.30                       40.82  ...
#
#    Max. Init. Time / s  Presim. Time / s  Sim. Time / s  \
# 0                 2.02             15.74         285.94
# 1                 2.40             15.90         285.62
# 2                 6.08              6.38         120.62
#
#    Virt. Memor  y (Sum) / kB  Local Spike Counter (Sum)  Average Rate (Sum)  \
# ...

# %%
task2=df.iloc[3:-2]
task2
# Out:
#    id  Nodes  Tasks/Node  Threads/Task  Runtime Program / s  Scale  Plastic  \
# 3   5      2           2             4               164.16     10     True
# 4   5      2           4             4                77.68     10     True
# 5   5      2           2             8                79.60     10     True
#
#    Avg. Neuron Build Time / s  Min. Edge Build Tim  e / s  \
# 3                        0.20                       40.03
# 4                        0.13                       20.93
# 5                        0.20                       21.63
#
#    Max. Edge Build Time / s  ...  Max. Init. Time / s  Presim. Time / s  \
# 3                     41.09  ...                 1.58              6.08
# 4                     21.22  ...                 0.46              3.12
# 5                     21.91  ...                 0.47              2.98
#
#    Sim. Time / s  Virt. Memor  y (Sum) / kB  Local Spike Counter (Sum)  \
# ...

# %% [markdown]
# ### Task 3:
# Add a column to the Task2 frame form Task 2 called “Program_Runtime*2”
# which multiplies the Program Runtime by

# %%
task3=df
task3
# Out:
#    id  Nodes  Tasks/Node  Threads/Task  Runtime Program / s  Scale  Plastic  \
# 0   5      1           4             4               200.84     10     True
# 1   5      1           2             8               202.15     10     True
# 2   5      1           4             8                89.57     10     True
# 3   5      2           2             4               164.16     10     True
# 4   5      2           4             4                77.68     10     True
# 5   5      2           2             8                79.60     10     True
# 6   5      2           4             8                37.20     10     True
# 7   5      3           2             4                96.51     10     True
#
#    Avg. Neuron Build Time / s  Min. Edge Build Tim  e / s  \
# 0                        0.15                       46.03
# 1                        0.28                       47.98
# 2                        0.15                       20.41
# ...

# %%
task3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          8 non-null      int64
#  1   Nodes                       8 non-null      int64
#  2   Tasks/Node                  8 non-null      int64
#  3   Threads/Task                8 non-null      int64
#  4   Runtime Program / s         8 non-null      float64
#  5   Scale                       8 non-null      int64
#  6   Plastic                     8 non-null      bool
#  7   Avg. Neuron Build Time / s  8 non-null      float64
#  8   Min. Edge Build Tim  e / s  8 non-null      float64
#  9   Max. Edge Build Time / s    8 non-null      float64
#  10  Min. Init. Time / s         8 non-null      float64
#  11  Max. Init. Time / s         8 non-null      float64
#  12  Presim. Time / s            8 non-null      float64
# ...

# %%
task3["Program_Runtime*2"] = df["Runtime Program / s"].apply(lambda x: pd.Series(x * 2))
task3
# Out:
#    id  Nodes  Tasks/Node  Threads/Task  Runtime Program / s  Scale  Plastic  \
# 0   5      1           4             4               200.84     10     True
# 1   5      1           2             8               202.15     10     True
# 2   5      1           4             8                89.57     10     True
# 3   5      2           2             4               164.16     10     True
# 4   5      2           4             4                77.68     10     True
# 5   5      2           2             8                79.60     10     True
# 6   5      2           4             8                37.20     10     True
# 7   5      3           2             4                96.51     10     True
#
#    Avg. Neuron Build Time / s  Min. Edge Build Tim  e / s  \
# 0                        0.15                       46.03
# 1                        0.28                       47.98
# 2                        0.15                       20.41
# ...
